# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sb
from sklearn import datasets
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
spt=pd.read_csv('/Users/MARIAM/Downloads/iris.csv')

# %%
spt.head()
# Out:
#    Column1  Column2  Column3  Column4      Column5
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
# !pip install fastcluster

# %%
# !pip install pyclustering
# Out:
# ...
#      ---------------------------------------- 2.6/2.6 MB 29.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pyclustering: filename=pyclustering-0.10.1.2-py3-none-any.whl size=2395106 sha256=53ce39bee21f356e11ed954f49dad79d5978ee9c6caab10e878c333e8dd19137
#   Stored in directory: c:\users\mariam\appdata\local\pip\cache\wheels\e0\56\c2\abb6866a3fcd8a55862f1df8a18f57805c3a78fed9a9023cb9
# Successfully built pyclustering
# ...

# %%
#Notetaking
"""
iris=dataset.load_iris()  // to load the data into the variable x
x= iris.data

"""

# %%
#Use K-means clustering to cluster the iris dataset

#First,find the optinum number of cluster

#Load the iris datasets
iris= datasets.load_iris()
x= iris.data

# %%
#Performing the K-means clustering
kmeans= KMeans(n_clusters=3, random_state=0)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
#Visualizing the results
plt.scatter(x[:,0],x[:, 1], c=kmeans.labels_, cmap="viridis")
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c="red", marker="x")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")
plt.title("K-means clustering of Iris datasets")
plt.show()

# %%
#Use Hierarchical clustering to cluster the digit’s dataset
from sklearn.datasets import make_blobs
from sklearn.cluster import Birch

#Generating synthentic dataset
x, y=make_blobs(n_samples=50, centers=3, random_state=42 )

sb.scatterplot(x[:, 0], x[:, 1], hue=y)
# Out:
# C:\APPS\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
